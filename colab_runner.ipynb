# %% [markdown]
# # Ejecutar `big-data-parcial-t2` en Google Colab
#
# Este notebook prepara el entorno y ejecuta el experimento principal del proyecto.

# %%
import os

REPO_URL = "https://github.com/uni-maestria/big-data-parcial-t2.git"
REPO_DIR = "big-data-parcial-t2"

if not os.path.isdir(REPO_DIR):
    # !git clone {REPO_URL}

os.chdir(REPO_DIR)
print("Directorio actual:", os.getcwd())

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Verificar datasets
#
# Asegúrate de tener estas carpetas dentro de `data/` antes de entrenar:
# - `data/DRIVE`
# - `data/CHASE_DB1`

# %%
import os

required_paths = ["data/DRIVE", "data/CHASE_DB1"]
for path in required_paths:
    print(path, "OK" if os.path.exists(path) else "NO ENCONTRADO")

# %%
# Ajusta --epochs según tu tiempo y recursos
# !python run_experiment.py --drive_root data/DRIVE --chase_root data/CHASE_DB1 --epochs 100 --results_dir results/ --run_ablation
